# %% [markdown]
# # Analyzing stock in R using Quantmod and TTR

# %% [markdown]
# #install.packages('quantmod')
# #install.packages('TTR')

# %%
library('TTR')
library('quantmod')
# Out:
# Loading required package: xts
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %%
df_intc <- getSymbols('INTC',src='yahoo',auto.assign=FALSE)
# Out:
# ‘getSymbols’ currently uses auto.assign=TRUE by default, but will
# use auto.assign=FALSE in 0.5-0. You will still be able to use
# ‘loadSymbols’ to automatically load data. getOption("getSymbols.env")
# and getOption("getSymbols.auto.assign") will still be checked for
# alternate defaults.
#
# This message is shown once per session and may be disabled by setting
# options("getSymbols.warning4.0"=FALSE). See ?getSymbols for details.

# %%
class(df_intc)
# Out:
# [1] "xts" "zoo"

# %%
nrow(df_intc)
# Out:
# [1] 3806

# %%
tail(df_intc,2)
# Out:
#            INTC.Open INTC.High INTC.Low INTC.Close INTC.Volume INTC.Adjusted
# 2022-02-10     49.18     49.93    48.76      48.86    32762700         48.86
# 2022-02-11     48.95     49.11    47.50      47.63    37186800         47.63

# %%
plot(df_intc$INTC.Close,main = 'Intel Stock Price')
# Out:
# plot without title

# %%
chart_Series(df_intc$INTC.Close,name="Intel Stock Price")
# Out:
# plot without title

# %%
chartSeries(df_intc,name="Intel Stock Price",theme = 'white')
# Out:
# Plot with title “[2007-01-03/2022-02-11]”

# %%
chartSeries(df_intc,name="Intel Stock Price",theme = 'white',subset='2018::2020')
# Out:
# Plot with title “[2018-01-02/2020-12-31]”
